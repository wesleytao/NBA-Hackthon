# %%
import pandas as pd
import numpy as np

# %%
event_code=pd.read_csv("../data/NBA Hackathon - Event Codes.txt",sep='\t')
play_by_play=pd.read_csv("../data/NBA Hackathon - Play by Play Data Sample (50 Games).txt",sep='\t')
Game_lineup=pd.read_csv("../data/NBA Hackathon - Game Lineup Data Sample (50 Games).txt",sep='\t')

# %%
Game_lineup.to_csv("../output/game_lineup.csv",index=False)

# %%
event_code
# Out:
#      Event_Msg_Type  Action_Type                Event_Msg_Type_Description  \
# 0                 1            0  Made Shot
# 1                 1            1  Made Shot
# 2                 1            3  Made Shot
# 3                 1            4  Made Shot
# 4                 1            5  Made Shot
# 5                 1            6  Made Shot
# 6                 1            7  Made Shot
# 7                 1            8  Made Shot
# 8                 1            9  Made Shot
# 9                 1           40  Made Shot
# 10                1           41  Made Shot
# 11                1           42  Made Shot
# 12                1           44  Made Shot
# 13                1           45  Made Shot
# 14                1           47  Made Shot
# 15                1           48  Made Shot
# 16                1           49  Made Shot
# 17                1           50  Made Shot
# 18                1           52  Made Shot
# 19                1           54  Made Shot
# ...

# %%
Game_lineup.head()
# Out:
#                             Game_id  Period                         Person_id  \
# 0  021fd159b55773fba8157e2090fe0fe2       1  881f83d2dee3f18c7d1751659406144e
# 1  021fd159b55773fba8157e2090fe0fe2       1  27ea17a8685c4919f157e83fe9cb2d9e
# 2  021fd159b55773fba8157e2090fe0fe2       1  57bbd7e30bc694aeee9ee40c583e6811
# 3  021fd159b55773fba8157e2090fe0fe2       1  cec898a1d355dbfbad8c760615fde1af
# 4  021fd159b55773fba8157e2090fe0fe2       1  33963fe856a1523ff46438ba07d1d99f
#
#                             Team_id status
# 0  012059d397c0b7e5a30a5bb89c0b075e      A
# 1  cff694c8186a4bd377de400e4f60fe47      A
# 2  cff694c8186a4bd377de400e4f60fe47      A
# 3  012059d397c0b7e5a30a5bb89c0b075e      A
# 4  cff694c8186a4bd377de400e4f60fe47      A

# %%
Game_lineup.to_csv("../output/game_lineup.csv",index=False)

# %%
play_by_play.to_csv("../output/play_by_play.csv",index=False)

# %%
event_code.to_csv("../output/event_code.csv",index=False)

# %%
event_code.head()
# Out:
#    Event_Msg_Type  Action_Type                Event_Msg_Type_Description  \
# 0               1            0  Made Shot
# 1               1            1  Made Shot
# 2               1            3  Made Shot
# 3               1            4  Made Shot
# 4               1            5  Made Shot
#
#                     Action_Type_Description
# 0  No Shot
# 1  Jump Shot
# 2  Hook Shot
# 3  Tip Shot
# 4  Layup Shot

# %%
play_by_play.head()
# Out:
#                             Game_id  Event_Num  Event_Msg_Type  Period  \
# 0  021fd159b55773fba8157e2090fe0fe2          0              12       1
# 1  021fd159b55773fba8157e2090fe0fe2          1              10       1
# 2  021fd159b55773fba8157e2090fe0fe2          2               2       1
# 3  021fd159b55773fba8157e2090fe0fe2          3               4       1
# 4  021fd159b55773fba8157e2090fe0fe2          6               6       1
#
#    WC_Time  PC_Time  Action_Type  Option1  Option2  Option3  \
# 0   546427     7200            0        0        0        0
# 1   546495     7200            0        0        0        0
# 2   546665     7050            1        3        0        0
# 3   546714     6960            0        0        0        0
# 4   546886     6920            4        0        0        0
#
#                             Team_id                           Person1  \
# 0  1473d70e5646a26de3c52aa1abd85b1f  6bcf6c1f8c373d25fca1579bc4464a91
# ...
